# %% [markdown]
# <h1>Shared compounds</h1>

# %%
import os
import re
import math
from collections import defaultdict
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import seaborn as sns; sns.set()
import json
import numpy as np
import itertools

# Define charts settings
plt.rc('xtick',labelsize=14)
plt.rcParams["figure.figsize"] = (12, 8)
plt.rcParams["legend.framealpha"] = 1

# Select whether the experiment should be replicated or whether to fix bugs
fix_bugs = False

# %% [markdown]
# <h3>Load data</h3>

# %%
# Load list of compounds
with open(os.path.join('src', 'unique_compounds.txt'),"r") as input_dict:
    list_of_words=[]
    for line in input_dict:
        # ORIGINAL
        if not fix_bugs:
            # BUG: There are remaining \t signs in some words, e.g. 'þunwange\t'
            list_of_words+=line.strip("\n.").split(" ")
        # BUG FIXED
        else:
            wrds = line.strip("\n.").split(" ")
            list_of_words += [w.strip() for w in wrds]

# %%
# Load all words in corpus
with open(os.path.join('src', 'calgary_proce_x.txt'),"r") as input_file:
    words=[]
    for line in input_file:
        words+=line.strip("\n.").split(" ")

# %%
# Locate compounds in particular texts
title = ''
lineno = 1
linenobeo = 1
endline = '#'
locations = defaultdict(lambda: defaultdict(list))
line_counts = defaultdict(int)

for word in words:
    if '{' in word or '}' in word:
        if lineno > 1:
            line_counts[title] = lineno
        title = re.sub('[\{\}]', '', word)
        title = re.sub('christ3iii', 'christiii', title)
        lineno = 1
    if '#' in word:
        lineno += 1
        if title.startswith('beowulf'):
            linenobeo += 1
    if len(word) <= 3:
        continue
    
    for dword in list_of_words:
        is_compound = False
        if dword in word:
            locations[title][dword].append(lineno)
            if title.startswith('beowulf'):
                locations['beowulf'][dword].append(linenobeo)

# %% [markdown]
# <div style="border-top: 10px solid #a6a6a6; margin-top: 30px; margin-bottom:20px"></div>
#
# <h3>Replicate Figure</h3>
# <p>
# We try to replicate Figure 3 using the theoretical model produced by matlab code (OECompClustNHB.m) and frequency tables provided by authors (OEdat_by_comp.mat). We do not merge Beowulf1 and Beowulf2, so the only comparable value to the article for these text is the value Beowulf1 to Beowulf2.
# <ul><li>The result is pretty far from that given in Figure 3, especially it seems that ratio for Beowulf1-Beowulf2 is a way lower than in the article (cf. here, where precise ratios are given by the authors).</li></ul>

# %%
shared_compounds = defaultdict(dict)
selected_texts = ['christii', 'elene', 'thefatesoftheapostles', 'juliana', 
                  'andreas', 'guthlacb', 'phoenix','beowulf1', 'beowulf2',]

# Get compounds shared in pairs of selected texts and store it in pandas dataframe
for t1 in selected_texts:
    for t2 in selected_texts:
        if t1 == t2:
            continue
        cmp1 = set(locations[t1].keys())
        cmp2 = set(locations[t2].keys())
        cmp1.difference_update({'wuldorcyning', 'heofoncyning', 'heofonrice', 'middangeard'})
        shared_compounds[t1][t2] = len(cmp1.intersection(cmp2))
                
df_real = pd.DataFrame.from_dict(shared_compounds).fillna(0)

# Load text names
with open('src/compounds_prior_names.json') as f:  
    header = json.load(f)

# Unify names with the ones in dataframes            
for i,x in enumerate(header['names']):
    header['names'][i] = re.sub('thephoenix', 'phoenix', header['names'][i])
    header['names'][i] = header['names'][i].lower()
            
# Load data
df_prior = pd.read_csv('src/compounds_prior.csv', header=None, index_col=False)
df_prior.index = header['names']
df_prior.columns = header['names']
   
# Divide real frequencies by theoretical model
df_scores =  df_real / df_prior

# Sort dataframe as in original figure
df_scores = df_scores.reindex(index=selected_texts, columns=selected_texts)

# Extract lower triangular matrix
mask = np.tril(np.ones_like(df_scores, dtype=np.bool), k=-1)
df_scores = df_scores.where(mask)

# Plot the heatmap
ax = sns.heatmap(df_scores.iloc[1:, :-1], annot=True, cmap='Purples')
plt.show()

# %% [markdown]
# <div style="border-top: 3px solid #a6a6a6; margin-top: 30px; margin-bottom:20px"></div>
# To check whether perhaps frequency tables are somehow corrupted, we have recalculated them from the textual data and generated random model again. (python code to extract frequencies and matlab code to generate the model are stored in the [compounds_model] folder)
# <ul><li>The result seems more or less similar to the one above. The differences may be caused by the fact, that the texts employed in the original tables slightly differ from those in the corpus.</li></ul>

# %%
# Load text names
with open('compounds_model/compounds_prior_names.json') as f:  
    header2 = json.load(f)
            
# Load data
df_prior2 = pd.read_csv('compounds_model/compounds_prior.csv', header=None, index_col=False)
df_prior2.index = header2['names']
df_prior2.columns = header2['names']
   
# Divide real frequencies by theoretical model
df_scores =  df_real / df_prior2

# Sort dataframe as in original figure
df_scores = df_scores.reindex(index=selected_texts, columns=selected_texts)

# Extract lower triangular matrix
mask = np.tril(np.ones_like(df_scores, dtype=np.bool), k=-1)
df_scores = df_scores.where(mask)

# Plot the heatmap
ax = sns.heatmap(df_scores.iloc[1:, :-1], annot=True, cmap='Purples')

# %% [markdown]
# <div style="border-top: 3px solid #a6a6a6; margin-top: 30px; margin-bottom:20px"></div>
# Let's take a look at the values both models predict (lower triangular (purple) =original model, upper triangular (green) = new model)
# <ul><li>It's pretty symmetrical</li></ul>

# %%
# Sort dataframes as in original figure
df_prior_ = df_prior.reindex(index=selected_texts, columns=selected_texts)
df_prior2_ = df_prior2.reindex(index=selected_texts, columns=selected_texts)

# Extract lower triangular matrix for original model (Purple) and upper triangular matrix for new model (Green)
mask = np.tril(np.ones_like(df_prior_, dtype=np.bool), k=-1)
df_prior_ = df_prior_.where(mask)
mask = np.triu(np.ones_like(df_prior2_, dtype=np.bool), k=1)
df_prior2_ = df_prior2_.where(mask)

# Plot the heatmap
ax = sns.heatmap(df_prior_, annot=True, cmap='Purples', cbar=False)
ax = sns.heatmap(df_prior2_, annot=True, cmap='Greens', cbar=False)
plt.show()

# %% [markdown]
# <div style="border-top: 3px solid #a6a6a6; margin-top: 30px; margin-bottom:20px"></div>
# Let's take a look on how our results differ from the ones reported in the article. The table below shows the differences (except for Beowulf, where authors do not provide precise numbers).

# %%
data_reported = [
    [1],
    [0.457142857, 2.275],
    [1.164285714, 2.871428571, 2.564285714],
    [1.067857143, 1.914285714, 2.432142857, 2.314285714],
    [0.210714286, 0.714285714, 0.45, 0.95, 0.378571429],
    [0.603571429, 1.132142857, 2.046428571, 1.260714286, 0.603571429, 0.155714286],
]

df_scores_original = pd.DataFrame(data_reported, index=list(selected_texts[1:7]), columns=selected_texts[0:6])
diff = df_scores_original - df_scores.iloc[1:-2,0:-3 ]
ax = sns.heatmap(diff, annot=True, cmap='PRGn', cbar=False)

# %% [markdown]
# <div style="border-top: 10px solid #a6a6a6; margin-top: 30px; margin-bottom:20px"></div>
#
# <h3>Topic vs. Compounds</h3>
# <p>
# The data above doesn't say much about how does the topic related poems written by multiple authors behave in terms of these ratios (possible case of Beowulf). Let's try to incorporate Christ I and Christ III (Christ II already plotted).
# <ul><li>The results show that the correlation between Christ I-III poems (written by different authors) is stronger than between most of the Cynnewulf-signed poems. This suggests that this metric is (as one may expect) rather topic-related than author-related.

# %%
shared_compounds = defaultdict(dict)
selected_texts2 = ['christi', 'christii', 'christiii',
                  'elene', 'thefatesoftheapostles', 'juliana', 
                  'andreas', 'guthlacb', 'phoenix','beowulf1', 'beowulf2',]

# Get compounds shared in pairs of selected texts and store it in pandas dataframe
for t1 in selected_texts2:
    for t2 in selected_texts2:
        if t1 == t2:
            continue
        cmp1 = set(locations[t1].keys())
        cmp2 = set(locations[t2].keys())
        cmp1.difference_update({'wuldorcyning', 'heofoncyning', 'heofonrice', 'middangeard'})
        shared_compounds[t1][t2] = len(cmp1.intersection(cmp2))
                
df_real = pd.DataFrame.from_dict(shared_compounds).fillna(0)

# Load text names
with open('compounds_model/compounds_prior_names.json') as f:  
    header = json.load(f)

# Unify names with the ones in dataframes            
for i,x in enumerate(header['names']):
    header['names'][i] = re.sub('thephoenix', 'phoenix', header['names'][i])
    header['names'][i] = header['names'][i].lower()
            
# Load data
df_prior = pd.read_csv('compounds_model/compounds_prior.csv', header=None, index_col=False)
df_prior.index = header['names']
df_prior.columns = header['names']
   
# Divide real frequencies by theoretical model
df_scores =  df_real / df_prior

# Sort dataframe as in original figure
df_scores = df_scores.reindex(index=selected_texts2, columns=selected_texts2)

# Extract lower triangular matrix
mask = np.tril(np.ones_like(df_scores, dtype=np.bool), k=-1)
df_scores = df_scores.where(mask)

# Plot the heatmap
ax = sns.heatmap(df_scores.iloc[1:, :-1], annot=True, cmap='Purples')

# %% [markdown]
# <div style="border-top: 3px solid #a6a6a6; margin-top: 30px; margin-bottom:20px"></div>
#
# Finally to the question why Fates of the Apostles tends to have exceptionally high correlation with most of the other texts.
# <ul><li>
# FotA is exceptional as each of the 13 compounds (+'middangeard') found in it is occuring only once (see its type-token compounds ratio compared to other poems below). The random model thus asigns a low probablity of shared compounds with other texts to it.
# </ul></li>

# %%
print(locations['thefatesoftheapostles'].keys())

selected_texts = ['christi', 'christii', 'christiii', 
                  'elene', 'thefatesoftheapostles', 'juliana', 
                  'andreas', 'guthlacb', 'phoenix','beowulf1', 'beowulf2',]
ttr = list()

for t in selected_texts:
    types = 0
    tokens = 0
    for w in locations[t]:
        if w in ('wuldorcyning', 'heofoncyning', 'heofonrice', 'middangeard'):
            continue
        tokens += len(locations[t][w])
        types += 1
    ttr.append(types/tokens)

y_pos = np.arange(len(selected_texts))
plt.bar(y_pos, ttr, align='center', alpha=0.5)
plt.xticks(y_pos, selected_texts, rotation='vertical')
plt.show()
# Out:
# dict_keys(['middangeard', 'apostolhad', 'werþeod', 'ordfruma', 'boldwela', 'beaducræft', 'lifwela', 'wundorcræfte', 'æfest', 'lindgelaces', 'sigelean', 'eardwic', 'wælreaf', 'foreþanc'])

# %% [markdown]
# <div style="border-top: 3px solid #a6a6a6; margin-top: 30px; margin-bottom:20px"></div>
#
# Now we just replicate the main chart in a way as published in the article - beowulf:beowulf displays data for beowulf1:beowulf2, with other poems the entire text of Beowulf is compared

# %%
shared_compounds = defaultdict(dict)
selected_texts3 = ['christi', 'christii', 'christiii',
                  'elene', 'thefatesoftheapostles', 'juliana', 
                  'andreas', 'guthlacb', 'phoenix','beowulf']

# Get compounds shared in pairs of selected texts and store it in pandas dataframe
for t1 in selected_texts2:
    for t2 in selected_texts2:

        if t1 != 'beowulf' and t1 == t2:
            continue          

        if t1 == t2:
            t1_ = 'beowulf1'
            t2_ = 'beowulf2'
        else:
            t1_ = t1
            t2_ = t2

        cmp1 = set(locations[t1_].keys())
        cmp2 = set(locations[t2_].keys())
        cmp1.difference_update({'wuldorcyning', 'heofoncyning', 'heofonrice', 'middangeard'})
        shared_compounds[t1][t2] = len(cmp1.intersection(cmp2))
                
df_real = pd.DataFrame.from_dict(shared_compounds).fillna(0)

# Load text names
with open('src/compounds_prior_names.json') as f:  
    header = json.load(f)

# Unify names with the ones in dataframes            
for i,x in enumerate(header['names']):
    header['names'][i] = re.sub('thephoenix', 'phoenix', header['names'][i])
    header['names'][i] = header['names'][i].lower()
    # Rename beowulf1 (where model for entire poem is stored) to beowulf
    header['names'][i] = re.sub('beowulf1', 'beowulf', header['names'][i])
            
# Load data
df_prior = pd.read_csv('src/compounds_prior_beowulf.csv', header=None, index_col=False)
df_prior.index = header['names']
df_prior.columns = header['names']

# Rewrite beowulf:beowulf value with beowulf:beowulf2
df_prior.loc['beowulf', 'beowulf'] = df_prior.loc['beowulf', 'beowulf2']

# Divide real frequencies by theoretical model
df_scores =  df_real / df_prior

# Sort dataframe as in original figure
df_scores = df_scores.reindex(index=selected_texts2, columns=selected_texts3)

# Extract lower triangular matrix
mask = np.tril(np.ones_like(df_scores, dtype=np.bool), k=0)
df_scores = df_scores.where(mask)

# Plot the heatmap
ax = sns.heatmap(df_scores[1:], annot=True, cmap='Purples')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8de13fe7e421> in <module>()
#       5
#       6 # Get compounds shared in pairs of selected texts and store it in pandas dataframe
# ----> 7 for t1 in selected_texts2:
#       8     for t2 in selected_texts2:
#       9
#
# NameError: name 'selected_texts2' is not defined

# %% [markdown]
# <div style="border-top: 3px solid #a6a6a6; margin-top: 30px; margin-bottom:20px"></div>
#
# Of course there's no proper research without hairball style network graph :)

# %%
import networkx as nx
test = defaultdict(dict)

for t1 in selected_texts2:
    for t2 in selected_texts2:
        if t1 == t2:
            continue
        cmp1 = set(locations[t1].keys())
        cmp2 = set(locations[t2].keys())
        cmp1.difference_update({'wuldorcyning', 'heofoncyning', 'heofonrice', 'middangeard'})
        for w in cmp1.intersection(cmp2):
            test[t1][w] = 1
            test[t2][w] = 1
            test[w][t1] = 1
            test[w][t1] = 1

df_net = pd.DataFrame.from_dict(test).fillna(0)
graph = nx.from_numpy_matrix(df_net.values)
graph = nx.relabel_nodes(graph, dict(enumerate(df_net.columns)))
color_map = list()
for node in graph:
    if node in selected_texts:
        color_map.append('#8FBC8F')
    else:
        color_map.append('#a6a6a6')
nx.draw(graph, node_color = color_map, with_labels = True, node_size=200)
plt.show()

# %%
df_scores
# Out:
#                        christii     elene  thefatesoftheapostles   juliana  \
# christii                    NaN       NaN                    NaN       NaN
# elene                  0.938527       NaN                    NaN       NaN
# thefatesoftheapostles  0.944020  1.467208                    NaN       NaN
# juliana                1.259129  1.498897               2.934846       NaN
# andreas                0.812602  1.091601               1.784068  1.289657
# guthlacb               0.691384  0.873897               0.791891  0.881197
# phoenix                1.045879  1.150748               3.263175  1.244046
# beowulf1               0.761169  0.664740               1.096852  0.538245
# beowulf2               0.245456  0.617475               0.000000  0.881046
#
#                         andreas  guthlacb   phoenix  beowulf1  beowulf2
# christii                    NaN       NaN       NaN       NaN       NaN
# elene                       NaN       NaN       NaN       NaN       NaN
# thefatesoftheapostles       NaN       NaN       NaN       NaN       NaN
# juliana                     NaN       NaN       NaN       NaN       NaN
# andreas                     NaN       NaN       NaN       NaN       NaN
# guthlacb               0.732562       NaN       NaN       NaN       NaN
# phoenix                0.793693  0.437490       NaN       NaN       NaN
# beowulf1               0.607021  0.634363  0.442957       NaN       NaN
# beowulf2               0.476907  0.615783  0.103561  1.095628       NaN

# %%
# Sort dataframes as in original figure
df_prior_ = df_prior.reindex(index=selected_texts, columns=selected_texts)
df_prior2_ = df_prior2.reindex(index=selected_texts, columns=selected_texts)

# Extract lower triangular matrix for original model (Purple) and upper triangular matrix for new model (Green)
mask = np.tril(np.ones_like(df_prior_, dtype=np.bool), k=-1)
df_prior_ = df_prior_.where(mask)
mask = np.tril(np.ones_like(df_prior2_, dtype=np.bool), k=1)
df_prior2_ = df_prior2_.where(mask)

f=plt.figure()

df3=(df_prior_-df_prior2_)/df_prior_
df3
ax = sns.heatmap(abs(df3), annot=True, cmap='PRGn', cbar=False)
plt.show()
f.savefig("foo.pdf", bbox_inches='tight')

# %%
data_reported = [
    [1],
    [0.457142857, 2.275],
    [1.164285714, 2.871428571, 2.564285714],
    [1.067857143, 1.914285714, 2.432142857, 2.314285714],
    [0.210714286, 0.714285714, 0.45, 0.95, 0.378571429],
    [0.603571429, 1.132142857, 2.046428571, 1.260714286, 0.603571429, 0.155714286],
]

df_scores_original = pd.DataFrame(data_reported, index=list(selected_texts[1:7]), columns=selected_texts[0:6])
diff = df_scores_original - df_scores.iloc[1:-2,0:-3 ]
ax = sns.heatmap(diff, annot=True, cmap='PRGn', cbar=False)
plt.show()

# %%
locations
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'beowulf1': defaultdict(list,
#                          {'þeodcyning': [2],
#                           'ymbsittend': [9, 1826],
#                           'liffrea': [16],
#                           'feohgiftum': [21],
#                           'landfruma': [31],
#                           'hringedstefna': [32, 1130, 1896],
#                           'feorweg': [37],
#                           'þeodgestreon': [44, 1217],
#                           'frumsceaft': [45, 91],
#                           'garsecg': [49, 514, 536],
#                           'leodcyning': [54],
#                           'healsgebedda': [63],
#                           'heresped': [64],
#                           'healreced': [68, 1980],
#                           'middangeard': [75, 503, 750, 1770],
#                           'folcstede': [76, 1462],
#                           'healærna': [78],
#                           'ecghete': [84, 1737],
#                           'landbuend': [95],
#                           'drihtguman': [99, 1387],
#                           'mearcstapa': [103, 1347],
#                           'fifelcynnes': [104],
#                           'wælfyll': [125],
#                           'morgensweg': [129],
#                           'feorhbealo': [155, 2249],
#                           'deaþscua': [159],
#                           'sinnihte': [160],
#                           'gifstol': [167],
#                           'modsefa': [179, 348, 1852, 2011],
#                           'sundwudu': [207, 1905],
#                           'antid': [218],
#                           'wundenstefna': [219],
#                           'brimclifu': [221],
#                           'yþlade': [227],
#                           'holmclif': [229, 1420, 1634],
#                           'fyrdsearu': [231],
#                           'modgehygd': [232],
#                           'mægenwudu': [235],
#                           'leafnesword': [244],
#                           'seldguma': [248],
#                           'frumcyn': [251],
#                           'feorbuend': [253],
#                           'wordhord': [258],
#                           'gumcynn': [259, 943],
#                           'ordfruma': [262],
#                           'hrafyl': [276],
#                           'cearwylmas': [281],
#                           'heahstede': [284],
#                           'maguþegn': [292, 2078],
#                           'lagustream': [296],
#                           'foldbuend': [308, 1354, 2273],
#                           'hringiren': [321],
#                           'æscholt': [329],
#                           'irenþreat': [329],
#                           'grimhelm': [333],
#                           'heresceafta': [334],
#                           'elþeod': [335],
#                           'ealdfæder': [372],
#                           'gifsceattas': [377],
#                           'mægencræft': [379],
#                           'mundgripe': [379, 752, 964, 1533, 1937],
#                           'heregriman': [395, 2048],
#                           'hildebord': [396],
#                           'wælsceaftas': [397],
#                           'orþancum': [405],
#                           'freowine': [429],
#                           'geolorand': [437],
#                           'angenga': [448],
#                           'beaduscrud': [452],
#                           'herebrogan': [461],
#                           'hordburh': [466],
#                           'heteþancum': [474],
#                           'fletwerod': [475],
#                           'dolsceaðan': [478],
#                           'beorsele': [481, 491, 1093],
#                           'morgentid': [483, 517],
#                           'bencþelu': [485, 1238],
#                           'heorudreor': [486],
#                           'beadurune': [500],
#                           'merefaran': [501],
#                           'dolgilpe': [508],
#                           'flodyþum': [541],
#                           'beadohrægl': [551],
#                           'hildebil': [556, 1519, 1665],
#                           'meredeor': [557],
#                           'laðgeteona': [558, 973],
#                           'egstream': [576],
#                           'morgenleoht': [603, 916],
#                           'feondgrapum': [635],
#                           'gilpcwide': [639],
#                           'folccwen': [640],
#                           'sigefolc': [643],
#                           'winærnes': [653],
#                           'mægenellen': [658],
#                           'ellenweorc': [660, 957, 1463],
#                           'seleweard': [666],
#                           'sundornytte': [666],
#                           'eotonweard': [667],
#                           'guþgeweorca': [677],
#                           'niþgeweorca': [682],
#                           'hleorbolster': [687],
#                           'selereste': [689],
#                           'winsele': [694, 770],
#                           'sceadugenga': [702],
#                           'hornreced': [703],
#                           'goldsele': [714, 1252, 1638, 2082],
#                           'fyrbendum': [721],
#                           'banloca': [741, 817],
#                           'inwitþancum': [748],
#                           'fenhopu': [763],
#                           'dryhtsele': [766],
#                           'ceasterbuendum': [767],
#                           'foldbold': [772],
#                           'irenbend': [773, 997],
#                           'medubenc': [775, 1051],
#                           'cwealmcuman': [791],
#                           'aldorgedal': [804],
#                           'ellorgast': [806, 1620],
#                           'licsar': [814],
#                           'dægrim': [822],
#                           'nihtweorce': [826],
#                           'gifhealle': [837],
#                           'folctoga': [838],
#                           'lifgedal': [840],
#                           'feorhlastas': [845],
#                           'eormengrund': [858],
#                           'foldweg': [865, 1632],
#                           'ealdgesegena': [868],
#                           'beahhord': [893, 920],
#                           'werþeod': [898],
#                           'brydbure': [920],
#                           'landgeweorc': [937],
#                           'hordweorþunge': [951],
#                           'handsporu': [985],
#                           'hilderinc': [985, 1306, 1494, 1575],
#                           'beadufolme': [989],
#                           'gestsele': [993],
#                           'legerbedde': [1006],
#                           'gummanna': [1027],
#                           'ealobence': [1028],
#                           'heafodbeorge': [1029],
#                           'fætedhleore': [1035],
#                           'hildesetl': [1038],
#                           'heahcyninges': [1038],
#                           'heahcyning': [1038],
#                           'hordweard': [1046, 1851, 2292],
#                           'brimlade': [1050],
#                           'andgit': [1058],
#                           'foreþanc': [1059],
#                           'hildewisan': [1063],
#                           'healgamen': [1065],
#                           'lindplegan': [1072, 2038],
#                           'wealaf': [1083, 1097],
#                           'heahsetl': [1086],
#                           'sincgestreon': [1091, 1225],
#                           'morþorhetes': [1104],
#                           'beadorinca': [1108],
#                           'wælfyr': [1118],
#                           'bengeato': [1120],
#                           'laðbite': [1121],
#                           'isgebinde': [1132],
#                           'torngemot': [1139],
#                           'hildeleoman': [1142],
#                           'gleomannes': [1159],
#                           'bencsweg': [1160],
#                           'freodrihten': [1168],
#                           'goldwine': [1170, 1475, 1601],
#                           'hererinc': [1175],
#                           'beahsele': [1176],
#                           'metodsceaft': [1179],
#                           'healsbeaga': [1194],
#                           'sincfæt': [1199, 2230, 2299],
#                           'wælreaf': [1204],
#                           'hreawic': [1213],
#                           'wideferhþ': [1221],
#                           'dryhtguma': [1230, 1767],
#                           'geosceaft': [1233, 1265],
#                           'beorscealca': [1239],
#                           'hilderandas': [1241],
#                           'wæteregesa': [1259],
#                           'ecgbanan': [1261],
#                           'geosceaftgasta': [1265],
#                           'anwald': [1271],
#                           'deaþwic': [1274],
#                           'randwiga': [1297, 1792],
#                           'weaspelle': [1314],
#                           'healwudu': [1316],
#                           'runwita': [1324],
#                           'eaxlgestealla': [1325, 1713],
#                           'orlege': [1325],
#                           'handbanan': [1329],
#                           'earmsceapen': [1350, 2227],
#                           'wræclast': [1351],
#                           'fengelad': [1358],
#                           'fyrgenstream': [1358],
#                           'milgemearces': [1361],
#                           'holtwudu': [1368],
#                           'ealdgestreon': [1380, 1457],
#                           'fyrgenholt': [1392],
#                           'nicorhusa': [1410],
#                           'fyrgenbeamas': [1413],
#                           'seglrade': [1428],
#                           'flanbogan': [1432, 1743],
#                           'herestræl': [1434],
#                           'eoferspreotum': [1436],
#                           'herebyrne': [1442],
#                           'bancofa': [1444],
#                           'hildegrap': [1445],
#                           'inwitfeng': [1446],
#                           'meregrund': [1448, 2099],
#                           'sundgebland': [1449],
#                           'mægenfultuma': [1454],
#                           'hæftmece': [1456],
#                           'atertanum': [1458],
#                           'gryresiðas': [1461],
#                           'sweordfrecan': [1467],
#                           'gumcyst': [1485, 1722],
#                           'brimwylm': [1493],
#                           'fyrdhom': [1503],
#                           'brimwylf': [1505, 1598],
#                           'hrofsele': [1514],
#                           'fyrleoht': [1515],
#                           'grundwyrgenne': [1517],
#                           'merewif': [1518],
#                           'beadoleoma': [1522],
#                           'fyrdhrægl': [1526],
#                           'andlean': [1540],
#                           'breostnet': [1547],
#                           'herenet': [1552],
#                           'beadulace': [1560],
#                           'fetelhilt': [1562],
#                           'banhringas': [1566],
#                           'hildegicelum': [1605],
#                           'lidmanna': [1622],
#                           'wældreor': [1630],
#                           'wælstenge': [1637],
#                           'gumdryhten': [1641],
#                           'wliteseon': [1649],
#                           'ærgeweorc': [1678],
#                           'wundorsmiþa': [1680],
#                           'fyrngewinnes': [1688],
#                           'endelean': [1691],
#                           'wælfealle': [1710],
#                           'breosthord': [1718],
#                           'eorlscipe': [1726, 2132],
#                           'wundorbebodum': [1746],
#                           'ealdgewin': [1775, 1780],
#                           'symbelwynne': [1781],
#                           'fletsittend': [1787, 2021],
#                           'nihthelm': [1788],
#                           'seleþegn': [1793],
#                           'garholt': [1833],
#                           'feorcyþðe': [1837],
#                           'inwitniþas': [1857],
#                           'hringnaca': [1861],
#                           'luftacen': [1862],
#                           'breostwylm': [1876],
#                           'hygebendum': [1877],
#                           'hægsteald': [1888],
#                           'landweard': [1889],
#                           'hordgestreon': [1898],
#                           'batwearde': [1899],
#                           'brimstream': [1909],
#                           'hyðweard': [1913],
#                           'fætgold': [1920],
#                           'burhlocan': [1927],
#                           'sinfrea': [1933],
#                           'wælbende': [1935],
#                           'freoðuwebbe': [1941],
#                           'gumstole': [1951],
#                           'lifgesceafta': [1952],
#                           'eormencynnes': [1956],
#                           'lindgestealla': [1972],
#                           'feðegest': [1975],
#                           'orleghwil': [2001],
#                           'medudream': [2015],
#                           'beahwriðan': [2017],
#                           'leodhryre': [2029],
#                           'bongar': [2030],
#                           'dryhtbearn': [2034],
#                           'æscwiga': [2041],
#                           'garcwealm': [2042],
#                           'wigbealu': [2045],
#                           'wælstowe': [2050],
#                           'dryhtsibbe': [2067],
#                           'freondscipe': [2068],
#                           'leodsceaða': [2092],
#                           'lifwynn': [2096],
#                           'fyrnwita': [2122],
#                           'firgenstream': [2127],
#                           'leodfruma': [2129],
#                           'beorncyning': [2147],
#                           'heafodmaga': [2150],
#                           'eaforheafodsegn': [2151],
#                           'hildesceorp': [2154],
#                           'inwitnet': [2166],
#                           'bregostol': [2195],
#                           'leodscipe': [2196],
#                           'eðelriht': [2197],
#                           'hildemeceas': [2201],
#                           'bordhreoðan': [2202],
#                           'sigeþeod': [2203],
#                           'stanbeorh': [2212],
#                           'wyrmhord': [2220],
#                           'heteswengeas': [2223],
#                           'gryrebroga': [2226],
#                           'eormenlafe': [2233],
#                           'eorlgestreona': [2243],
#                           'seledream': [2251],
#                           'dryncfæt': [2253],
#                           'beadogriman': [2256],
#                           'herepad': [2257],
#                           'burhstede': [2264],
#                           'bealocwealm': [2264],
#                           'feorhcynna': [2265],
#                           'hordwynne': [2269],
#                           'fyrngeweorc': [2285]}),
#              'beowulf': defaultdict(list,
#                          {'þeodcyning': [2, 2692, 2961, 3006, 3084],
#                           'ymbsittend': [9, 1826],
#                           'liffrea': [16],
#                           'feohgiftum': [21],
#                           'landfruma': [31],
#                           'hringedstefna': [32, 1130, 1896],
#                           'feorweg': [37],
#                           'þeodgestreon': [44, 1217],
#                           'frumsceaft': [45, 91],
#                           'garsecg': [49, 514, 536],
#                           'leodcyning': [54],
#                           'healsgebedda': [63],
#                           'heresped': [64],
#                           'healreced': [68, 1980],
#                           'middangeard': [75, 503, 750, 1770, 2994],
#                           'folcstede': [76, 1462],
#                           'healærna': [78],
#                           'ecghete': [84, 1737],
#                           'landbuend': [95],
#                           'drihtguman': [99, 1387],
#                           'mearcstapa': [103, 1347],
#                           'fifelcynnes': [104],
#                           'wælfyll': [125, 3152],
#                           'morgensweg': [129],
#                           'feorhbealo': [155, 2249],
#                           'deaþscua': [159],
#                           'sinnihte': [160],
#                           'gifstol': [167, 2325],
#                           'modsefa': [179, 348, 1852, 2011, 2626],
#                           'sundwudu': [207, 1905],
#                           'antid': [218],
#                           'wundenstefna': [219],
#                           'brimclifu': [221],
#                           'yþlade': [227],
#                           'holmclif': [229, 1420, 1634],
#                           'fyrdsearu': [231],
#                           'modgehygd': [232],
#                           'mægenwudu': [235],
#                           'leafnesword': [244],
#                           'seldguma': [248],
#                           'frumcyn': [251],
#                           'feorbuend': [253],
#                           'wordhord': [258],
#                           'gumcynn': [259, 943, 2763],
#                           'ordfruma': [262],
#                           'hrafyl': [276],
#                           'cearwylmas': [281],
#                           'heahstede': [284],
#                           'maguþegn': [292, 2078],
#                           'lagustream': [296],
#                           'foldbuend': [308, 1354, 2273],
#                           'hringiren': [321],
#                           'æscholt': [329],
#                           'irenþreat': [329],
#                           'grimhelm': [333],
#                           'heresceafta': [334],
#                           'elþeod': [335],
#                           'ealdfæder': [372],
#                           'gifsceattas': [377],
#                           'mægencræft': [379],
#                           'mundgripe': [379, 752, 964, 1533, 1937],
#                           'heregriman': [395, 2048, 2603],
#                           'hildebord': [396, 3137],
#                           'wælsceaftas': [397],
#                           'orþancum': [405],
#                           'freowine': [429],
#                           'geolorand': [437],
#                           'angenga': [448],
#                           'beaduscrud': [452, 2658],
#                           'herebrogan': [461],
#                           'hordburh': [466],
#                           'heteþancum': [474],
#                           'fletwerod': [475],
#                           'dolsceaðan': [478],
#                           'beorsele': [481, 491, 1093],
#                           'morgentid': [483, 517],
#                           'bencþelu': [485, 1238],
#                           'heorudreor': [486],
#                           'beadurune': [500],
#                           'merefaran': [501],
#                           'dolgilpe': [508],
#                           'flodyþum': [541],
#                           'beadohrægl': [551],
#                           'hildebil': [556, 1519, 1665, 2677],
#                           'meredeor': [557],
#                           'laðgeteona': [558, 973],
#                           'egstream': [576],
#                           'morgenleoht': [603, 916],
#                           'feondgrapum': [635],
#                           'gilpcwide': [639],
#                           'folccwen': [640],
#                           'sigefolc': [643],
#                           'winærnes': [653],
#                           'mægenellen': [658],
#                           'ellenweorc': [660, 957, 1463, 2397, 2641, 3171],
#                           'seleweard': [666],
#                           'sundornytte': [666],
#                           'eotonweard': [667],
#                           'guþgeweorca': [677],
#                           'niþgeweorca': [682],
#                           'hleorbolster': [687],
#                           'selereste': [689],
#                           'winsele': [694, 770, 2454],
#                           'sceadugenga': [702],
#                           'hornreced': [703],
#                           'goldsele': [714, 1252, 1638, 2082],
#                           'fyrbendum': [721],
#                           'banloca': [741, 817],
#                           'inwitþancum': [748],
#                           'fenhopu': [763],
#                           'dryhtsele': [766, 2318],
#                           'ceasterbuendum': [767],
#                           'foldbold': [772],
#                           'irenbend': [773, 997],
#                           'medubenc': [775, 1051],
#                           'cwealmcuman': [791],
#                           'aldorgedal': [804],
#                           'ellorgast': [806, 1620],
#                           'licsar': [814],
#                           'dægrim': [822],
#                           'nihtweorce': [826],
#                           'gifhealle': [837],
#                           'folctoga': [838],
#                           'lifgedal': [840],
#                           'feorhlastas': [845],
#                           'eormengrund': [858],
#                           'foldweg': [865, 1632],
#                           'ealdgesegena': [868],
#                           'beahhord': [893, 920, 2824],
#                           'werþeod': [898],
#                           'brydbure': [920],
#                           'landgeweorc': [937],
#                           'hordweorþunge': [951],
#                           'handsporu': [985],
#                           'hilderinc': [985, 1306, 1494, 1575, 3122, 3134],
#                           'beadufolme': [989],
#                           'gestsele': [993],
#                           'legerbedde': [1006],
#                           'gummanna': [1027],
#                           'ealobence': [1028],
#                           'heafodbeorge': [1029],
#                           'fætedhleore': [1035],
#                           'hildesetl': [1038],
#                           'heahcyninges': [1038],
#                           'heahcyning': [1038],
#                           'hordweard': [1046, 1851, 2292, 2300, 2552, 2591],
#                           'brimlade': [1050],
#                           'andgit': [1058],
#                           'foreþanc': [1059],
#                           'hildewisan': [1063],
#                           'healgamen': [1065],
#                           'lindplegan': [1072, 2038],
#                           'wealaf': [1083, 1097],
#                           'heahsetl': [1086],
#                           'sincgestreon': [1091, 1225],
#                           'morþorhetes': [1104],
#                           'beadorinca': [1108],
#                           'wælfyr': [1118, 2580],
#                           'bengeato': [1120],
#                           'laðbite': [1121],
#                           'isgebinde': [1132],
#                           'torngemot': [1139],
#                           'hildeleoman': [1142, 2581],
#                           'gleomannes': [1159],
#                           'bencsweg': [1160],
#                           'freodrihten': [1168],
#                           'goldwine': [1170, 1475, 1601, 2417, 2582],
#                           'hererinc': [1175],
#                           'beahsele': [1176],
#                           'metodsceaft': [1179, 2813],
#                           'healsbeaga': [1194],
#                           'sincfæt': [1199, 2230, 2299],
#                           'wælreaf': [1204],
#                           'hreawic': [1213],
#                           'wideferhþ': [1221],
#                           'dryhtguma': [1230, 1767],
#                           'geosceaft': [1233, 1265],
#                           'beorscealca': [1239],
#                           'hilderandas': [1241],
#                           'wæteregesa': [1259],
#                           'ecgbanan': [1261],
#                           'geosceaftgasta': [1265],
#                           'anwald': [1271],
#                           'deaþwic': [1274],
#                           'randwiga': [1297, 1792],
#                           'weaspelle': [1314],
#                           'healwudu': [1316],
#                           'runwita': [1324],
#                           'eaxlgestealla': [1325, 1713],
#                           'orlege': [1325, 2405],
#                           'handbanan': [1329],
#                           'earmsceapen': [1350, 2227],
#                           'wræclast': [1351],
#                           'fengelad': [1358],
#                           'fyrgenstream': [1358],
#                           'milgemearces': [1361],
#                           'holtwudu': [1368, 2338],
#                           'ealdgestreon': [1380, 1457],
#                           'fyrgenholt': [1392],
#                           'nicorhusa': [1410],
#                           'fyrgenbeamas': [1413],
#                           'seglrade': [1428],
#                           'flanbogan': [1432, 1743],
#                           'herestræl': [1434],
#                           'eoferspreotum': [1436],
#                           'herebyrne': [1442],
#                           'bancofa': [1444],
#                           'hildegrap': [1445, 2505],
#                           'inwitfeng': [1446],
#                           'meregrund': [1448, 2099],
#                           'sundgebland': [1449],
#                           'mægenfultuma': [1454],
#                           'hæftmece': [1456],
#                           'atertanum': [1458],
#                           'gryresiðas': [1461],
#                           'sweordfrecan': [1467],
#                           'gumcyst': [1485, 1722, 2541],
#                           'brimwylm': [1493],
#                           'fyrdhom': [1503],
#                           'brimwylf': [1505, 1598],
#                           'hrofsele': [1514],
#                           'fyrleoht': [1515],
#                           'grundwyrgenne': [1517],
#                           'merewif': [1518],
#                           'beadoleoma': [1522],
#                           'fyrdhrægl': [1526],
#                           'andlean': [1540],
#                           'breostnet': [1547],
#                           'herenet': [1552],
#                           'beadulace': [1560],
#                           'fetelhilt': [1562],
#                           'banhringas': [1566],
#                           'hildegicelum': [1605],
#                           'lidmanna': [1622],
#                           'wældreor': [1630],
#                           'wælstenge': [1637],
#                           'gumdryhten': [1641],
#                           'wliteseon': [1649],
#                           'ærgeweorc': [1678],
#                           'wundorsmiþa': [1680],
#                           'fyrngewinnes': [1688],
#                           'endelean': [1691],
#                           'wælfealle': [1710],
#                           'breosthord': [1718, 2790],
#                           'eorlscipe': [1726, 2132, 2620, 3005, 3171],
#                           'wundorbebodum': [1746],
#                           'ealdgewin': [1775, 1780],
#                           'symbelwynne': [1781],
#                           'fletsittend': [1787, 2021],
#                           'nihthelm': [1788],
#                           'seleþegn': [1793],
#                           'garholt': [1833],
#                           'feorcyþðe': [1837],
#                           'inwitniþas': [1857],
#                           'hringnaca': [1861],
#                           'luftacen': [1862],
#                           'breostwylm': [1876],
#                           'hygebendum': [1877],
#                           'hægsteald': [1888],
#                           'landweard': [1889],
#                           'hordgestreon': [1898, 3090],
#                           'batwearde': [1899],
#                           'brimstream': [1909],
#                           'hyðweard': [1913],
#                           'fætgold': [1920],
#                           'burhlocan': [1927],
#                           'sinfrea': [1933],
#                           'wælbende': [1935],
#                           'freoðuwebbe': [1941],
#                           'gumstole': [1951],
#                           'lifgesceafta': [1952, 3062],
#                           'eormencynnes': [1956],
#                           'lindgestealla': [1972],
#                           'feðegest': [1975],
#                           'orleghwil': [2001, 2425, 2909],
#                           'medudream': [2015],
#                           'beahwriðan': [2017],
#                           'leodhryre': [2029, 2389],
#                           'bongar': [2030],
#                           'dryhtbearn': [2034],
#                           'æscwiga': [2041],
#                           'garcwealm': [2042],
#                           'wigbealu': [2045],
#                           'wælstowe': [2050, 2982],
#                           'dryhtsibbe': [2067],
#                           'freondscipe': [2068],
#                           'leodsceaða': [2092],
#                           'lifwynn': [2096],
#                           'fyrnwita': [2122],
#                           'firgenstream': [2127],
#                           'leodfruma': [2129],
#                           'beorncyning': [2147],
#                           'heafodmaga': [2150],
#                           'eaforheafodsegn': [2151],
#                           'hildesceorp': [2154],
#                           'inwitnet': [2166],
#                           'bregostol': [2195, 2368, 2387],
#                           'leodscipe': [2196, 2749],
#                           'eðelriht': [2197],
#                           'hildemeceas': [2201],
#                           'bordhreoðan': [2202],
#                           'sigeþeod': [2203],
#                           'stanbeorh': [2212],
#                           'wyrmhord': [2220],
#                           'heteswengeas': [2223],
#                           'gryrebroga': [2226],
#                           'eormenlafe': [2233],
#                           'eorlgestreona': [2243],
#                           'seledream': [2251],
#                           'dryncfæt': [2253],
#                           'beadogriman': [2256],
#                           'herepad': [2257],
#                           'burhstede': [2264],
#                           'bealocwealm': [2264],
#                           'feorhcynna': [2265],
#                           'hordwynne': [2269],
#                           'fyrngeweorc': [2285],
#                           'heahgestreon': [2300],
#                           'drincfæt': [2304],
#                           'sincgifan': [2309],
#                           'bryneleoma': [2311],
#                           'lyftfloga': [2313],
#                           'ligdraca': [2331],
#                           'hordwelan': [2342],
#                           'widfloga': [2344, 2828],
#                           'hildehlemma': [2349, 2542],
#                           'freawine': [2355, 2427, 2436],
#                           'sundnytte': [2358],
#                           'feðewiges': [2362],
#                           'hildfrecan': [2364],
#                           'anhaga': [2366],
#                           'ælfylc': [2369],
#                           'freondlarum': [2375],
#                           'wræcmæcga': [2377],
#                           'feorhwunde': [2383],
#                           'holmwylme': [2409],
#                           'hornbogan': [2435],
#                           'wicstede': [2460, 2605],
#                           'gumdream': [2467],
#                           'inwitscear': [2476],
#                           'feorhsweng': [2487],
#                           'eðelwyn': [2491, 2883],
#                           'banhus': [2506, 3145],
#                           'beotwordum': [2508],
#                           'mansceaða': [2512],
#                           'helmberend': [2515, 2640],
#                           'heaðufyres': [2520],
#                           'stanbogan': [2543, 2716],
#                           'hildeswat': [2556],
#                           'bordrand': [2557],
#                           'hringbogan': [2559],
#                           'heaðuswenge': [2579],
#                           'hreðsigora': [2581],
#                           'handgesteallan': [2594],
#                           'hildecystum': [2596],
#                           'lindwig': [2601],
#                           'folcriht': [2606],
#                           'wordriht': [2629],
#                           'biorsele': [2633],
#                           'garwig': [2639, 2672, 2809],
#                           'gledegesa': [2648],
#                           'lichama': [2649, 3175],
#                           'ealdgewyrht': [2655],
#                           'wælrec': [2659],
#                           'inwitgæst': [2668],
#                           'fyrwylmum': [2669],
#                           'fyrdraca': [2687],
#                           'sibæðelingas': [2706],
#                           'sigehwila': [2708],
#                           'winedryhten': [2720, 3173],
#                           'dæghwila': [2724],
#                           'dogorgerim': [2726],
#                           'folccyning': [2731, 2871],
#                           'feorhbennum': [2738],
#                           'beadusercean': [2753],
#                           'uhtflogan': [2758],
#                           'fyrnmanna': [2759],
#                           'ealdhlaford': [2776],
#                           'ligegesan': [2778],
#                           'middelnihtum': [2780, 2831],
#                           'swyltdæge': [2796],
#                           'feorhlege': [2798],
#                           'endelaf': [2811],
#                           'breostgehygdum': [2816],
#                           'attorsceaðan': [2837],
#                           'hildlatan': [2844],
#                           'hildlata': [2844],
#                           'treowlogan': [2845],
#                           'feðecempa': [2851],
#                           'frumgar': [2854],
#                           'ealubence': [2865],
#                           'edwitlif': [2889],
#                           'endedogor': [2894],
#                           'eftcyme': [2894],
#                           'wælreste': [2900],
#                           'ealdorgewinna': [2901],
#                           'heafodweard': [2907],
#                           'flotherge': [2913],
#                           'brimwisan': [2928],
#                           'galgtreowum': [2938],
#                           'freoðowong': [2957],
#                           'feondscipe': [2997],
#                           'adfære': [3008],
#                           'elland': [3017],
#                           'herewisa': [3018],
#                           'gleodream': [3019],
#                           'fotgemearces': [3040],
#                           'lyftwynne': [3041],
#                           'meduseld': [3063],
#                           'goldweard': [3079],
#                           'burhwelan': [3098],
#                           'fulleode': [3117],
#                           'inwithrof': [3121],
#                           'æledleoman': [3123],
#                           'weallclif': [3130],
#                           'wudurec': [3142]}),
#              'beowulf2': defaultdict(list,
#                          {'heahgestreon': [1],
#                           'hordweard': [1, 253, 292],
#                           'drincfæt': [5],
#                           'sincgifan': [10],
#                           'bryneleoma': [12],
#                           'lyftfloga': [14],
#                           'dryhtsele': [19],
#                           'gifstol': [26],
#                           'ligdraca': [32],
#                           'holtwudu': [39],
#                           'hordwelan': [43],
#                           'widfloga': [45, 529],
#                           'hildehlemma': [50, 243],
#                           'freawine': [56, 128, 137],
#                           'sundnytte': [59],
#                           'feðewiges': [63],
#                           'hildfrecan': [65],
#                           'anhaga': [67],
#                           'bregostol': [69, 88],
#                           'ælfylc': [70],
#                           'freondlarum': [76],
#                           'wræcmæcga': [78],
#                           'feorhwunde': [84],
#                           'leodhryre': [90],
#                           'ellenweorc': [98, 342, 872],
#                           'orlege': [106],
#                           'holmwylme': [110],
#                           'goldwine': [118, 283],
#                           'orleghwil': [126, 610],
#                           'hornbogan': [136],
#                           'winsele': [155],
#                           'wicstede': [161, 306],
#                           'gumdream': [168],
#                           'inwitscear': [177],
#                           'feorhsweng': [188],
#                           'eðelwyn': [192, 584],
#                           'hildegrap': [206],
#                           'banhus': [207, 846],
#                           'beotwordum': [209],
#                           'mansceaða': [213],
#                           'helmberend': [216, 341],
#                           'heaðufyres': [221],
#                           'gumcyst': [242],
#                           'stanbogan': [244, 417],
#                           'hildeswat': [257],
#                           'bordrand': [258],
#                           'hringbogan': [260],
#                           'heaðuswenge': [280],
#                           'wælfyr': [281],
#                           'hildeleoman': [282],
#                           'hreðsigora': [282],
#                           'handgesteallan': [295],
#                           'hildecystum': [297],
#                           'lindwig': [302],
#                           'heregriman': [304],
#                           'folcriht': [307],
#                           'eorlscipe': [321, 706, 872],
#                           'modsefa': [327],
#                           'wordriht': [330],
#                           'biorsele': [334],
#                           'garwig': [340, 373, 510],
#                           'gledegesa': [349],
#                           'lichama': [350, 876],
#                           'ealdgewyrht': [356],
#                           'beaduscrud': [359],
#                           'wælrec': [360],
#                           'inwitgæst': [369],
#                           'fyrwylmum': [370],
#                           'hildebil': [378],
#                           'fyrdraca': [388],
#                           'þeodcyning': [393, 662, 707, 785],
#                           'sibæðelingas': [407],
#                           'sigehwila': [409],
#                           'winedryhten': [421, 874],
#                           'dæghwila': [425],
#                           'dogorgerim': [427],
#                           'folccyning': [432, 572],
#                           'feorhbennum': [439],
#                           'leodscipe': [450],
#                           'beadusercean': [454],
#                           'uhtflogan': [459],
#                           'fyrnmanna': [460],
#                           'gumcynn': [464],
#                           'ealdhlaford': [477],
#                           'ligegesan': [479],
#                           'middelnihtum': [481, 532],
#                           'breosthord': [491],
#                           'swyltdæge': [497],
#                           'feorhlege': [499],
#                           'endelaf': [512],
#                           'metodsceaft': [514],
#                           'breostgehygdum': [517],
#                           'beahhord': [525],
#                           'attorsceaðan': [538],
#                           'hildlatan': [545],
#                           'hildlata': [545],
#                           'treowlogan': [546],
#                           'feðecempa': [552],
#                           'frumgar': [555],
#                           'ealubence': [566],
#                           'edwitlif': [590],
#                           'endedogor': [595],
#                           'eftcyme': [595],
#                           'wælreste': [601],
#                           'ealdorgewinna': [602],
#                           'heafodweard': [608],
#                           'flotherge': [614],
#                           'brimwisan': [629],
#                           'galgtreowum': [639],
#                           'freoðowong': [658],
#                           'wælstowe': [683],
#                           'middangeard': [695],
#                           'feondscipe': [698],
#                           'adfære': [709],
#                           'elland': [718],
#                           'herewisa': [719],
#                           'gleodream': [720],
#                           'fotgemearces': [741],
#                           'lyftwynne': [742],
#                           'lifgesceafta': [763],
#                           'meduseld': [764],
#                           'goldweard': [780],
#                           'hordgestreon': [791],
#                           'burhwelan': [799],
#                           'fulleode': [818],
#                           'inwithrof': [822],
#                           'hilderinc': [823, 835],
#                           'æledleoman': [824],
#                           'weallclif': [831],
#                           'hildebord': [838],
#                           'wudurec': [843],
#                           'wælfyll': [853]}),
#              'andreas': defaultdict(list,
#                          {'heahcyning': [7],
#                           'folctoga': [9, 1459],
#                           'herefelda': [11, 19],
#                           'godspell': [13],
#                           'wundorcræfte': [14, 646],
#                           'igland': [16],
#                           'ellþeod': [17, 164, 679, 973, 1176, 1455, 1560],
#                           'mearcland': [20, 803],
#                           'folcstede': [21, 180],
#                           'dwolcræft': [35],
#                           'meteleaste': [40, 1158],
#                           'æscberend': [48, 1077, 1538],
#                           'orlege': [48, 1147, 1206, 1303],
#                           'heofonrice': [53, 57, 1053],
#                           'carcern': [58,
#                            91,
#                            131,
#                            992,
#                            1076,
#                            1083,
#                            1251,
#                            1461,
#                            1561,
#                            1579],
#                           'sigedryhten': [61, 1454],
#                           'elþeod': [64, 200, 281, 947, 1074],
#                           'eadgifa': [75, 452],
#                           'hearmcwide': [80, 562],
#                           'edwitspræce': [82],
#                           'middangeard': [83,
#                            162,
#                            225,
#                            228,
#                            346,
#                            702,
#                            1324,
#                            1373,
#                            1503,
#                            1719],
#                           'heofoncyning': [93, 724, 822, 999, 1382],
#                           'maguþegn': [95, 367, 1141],
#                           'hearmlocan': [96, 1030],
#                           'boldwela': [104, 525],
#                           'leodhete': [113, 1139, 1150],
#                           'tælmet': [114],
#                           'nihtgerimes': [116, 159],
#                           'eðelrice': [121, 433],
#                           'nihthelm': [124],
#                           'dægredwoma': [126],
#                           'dægred': [126],
#                           'hildfrecan': [127, 1071],
#                           'bordhreoðan': [129],
#                           'fyrstmearc': [134],
#                           'rimcræft': [135],
#                           'werþeod': [138, 544, 574],
#                           'dimscuan': [142],
#                           'heolstorlocan': [145, 1006],
#                           'ordfruma': [147, 684],
#                           'þinggemearces': [149],
#                           'banhringas': [151],
#                           'galdorcræftum': [167],
#                           'modhord': [173],
#                           'feorhgedal': [182, 1428],
#                           'handgewinne': [187],
#                           'wæterbrogan': [198, 457],
#                           'widland': [199],
#                           'foldweg': [207, 776],
#                           'hildewoman': [219],
#                           'beaducræft': [220],
#                           'ellenweorc': [233, 1371],
#                           'hildlata': [234],
#                           'garsecg': [239, 372, 393, 531],
#                           'brimstream': [240, 349, 904],
#                           'heofoncandel': [244],
#                           'lidweardas': [245],
#                           'merebate': [247],
#                           'scipferendum': [251],
#                           'ealiðendum': [252],
#                           'hranrade': [267, 635],
#                           'sincweorðunga': [273, 478],
#                           'hornscipe': [275],
#                           'leodmearce': [287, 778],
#                           'scipweardas': [298],
#                           'feohgestreon': [302],
#                           'merestream': [310, 455],
#                           'wordhord': [317, 602],
#                           'sarcwide': [321, 966],
#                           'wuldorþrymmes': [326, 703],
#                           'stedewang': [335, 775],
#                           'hygeþanc': [342, 818],
#                           'heahgestreon': [363],
#                           'hwælmere': [371],
#                           'hornfisc': [371],
#                           'holmwege': [383],
#                           'leohtfruma': [388, 1414],
#                           'lagufæsten': [399, 826],
#                           'beaduwange': [414],
#                           'wuldorcyning': [419, 802, 1431, 1448],
#                           'reordberend': [420],
#                           'lagustream': [424],
#                           'wuldorsped': [429],
#                           'wæteregesa': [436],
#                           'ealada': [442],
#                           'mereþyssan': [447],
#                           'gryrehwile': [469],
#                           'wordlocan': [471],
#                           'fætedsinces': [479],
#                           'freondscipe': [479],
#                           'heofonþrymme': [482, 1721],
#                           'wæterflod': [504],
#                           'andgit': [510],
#                           'brimhengest': [514],
#                           'flodwylm': [517],
#                           'heofonhwealfe': [546, 1403],
#                           'modsefa': [555, 893, 1210],
#                           'liffruma': [563, 1285],
#                           'cynebearn': [567],
#                           'grundwæge': [583],
#                           'heremægen': [587, 729, 1299, 1651],
#                           'teoncwide': [634, 772],
#                           'godbearn': [641],
#                           'sigesped': [647],
#                           'burhweard': [661],
#                           'sigedema': [662],
#                           'cynestol': [667],
#                           'huscworde': [670],
#                           'ealdorsacerd': [671],
#                           'hordlocan': [672],
# ...
#                           'geeadmeded': [147],
#                           'eadmed': [147],
#                           'wigbed': [159]}),
#              'resignation': defaultdict(list,
#                          {'regnþeof': [16],
#                           'wuldorcyning': [18],
#                           'heofoncyning': [31],
#                           'bibod': [36],
#                           'foreþonc': [39, 55],
#                           'wuldordream': [45],
#                           'æfest': [48],
#                           'modearfoþa': [88],
#                           'anhoga': [90],
#                           'leodwynna': [91],
#                           'sarcwide': [96]}),
#              'riddle1': defaultdict(list,
#                          {'hygecræft': [2],
#                           'wælcwealm': [9],
#                           'foldbuend': [14]}),
#              'riddle2': defaultdict(list,
#                          {'garsecg': [4], 'hwælmere': [6], 'sundhelm': [11]}),
#              'riddle3': defaultdict(list,
#                          {'aglac': [8],
#                           'wicstede': [10],
#                           'frumsceaft': [15],
#                           'streamgewinnes': [27],
#                           'hopgehnastes': [28],
#                           'lagustream': [39],
#                           'eoredþreat': [50],
#                           'orlege': [60],
#                           'wolcengehnaste': [61]}),
#              'riddle5': defaultdict(list,
#                          {'anhaga': [2],
#                           'beadoweorca': [3],
#                           'folcstede': [12]}),
#              'riddle8': defaultdict(list, {'heafodwoþe': [4]}),
#              'riddle10': defaultdict(list, {'firgenstream': [3]}),
#              'riddle11': defaultdict(list, {'geswic': [11]}),
#              'riddle12': defaultdict(list, {'druncmennen': [10]}),
#              'riddle14': defaultdict(list,
#                          {'hagosteald': [3],
#                           'merehengest': [7],
#                           'fyrdsceorp': [14],
#                           'folcwigan': [14]}),
#              'riddle15': defaultdict(list,
#                          {'wælhwelpes': [24],
#                           'guþgemotes': [27],
#                           'hildepilum': [29]}),
#              'riddle17': defaultdict(list,
#                          {'eodorwirum': [3],
#                           'dryhtgestreona': [4],
#                           'dægtid': [4]}),
#              'riddle19': defaultdict(list,
#                          {'hildeþryþe': [5], 'widlast': [7], 'siþfæt': [10]}),
#              'riddle20': defaultdict(list,
#                          {'wordlofes': [12],
#                           'hyhtplega': [29],
#                           'hagosteald': [32]}),
#              'riddle22': defaultdict(list,
#                          {'eoredmæcgas': [4],
#                           'fridhengestas': [5],
#                           'fæthengest': [15]}),
#              'riddle23': defaultdict(list,
#                          {'feorhbealo': [6], 'mandrinc': [14]}),
#              'riddle25': defaultdict(list, {'neahbuendum': [3]}),
#              'riddle26': defaultdict(list,
#                          {'binom': [3], 'beamtelge': [10], 'dryhtfolc': [18]}),
#              'riddle27': defaultdict(list,
#                          {'burghleoþum': [3], 'geswic': [13]}),
#              'riddle29': defaultdict(list, {'lyftfæt': [4], 'heresiþ': [5]}),
#              'riddle31': defaultdict(list, {'middangeard': [2]}),
#              'riddle32': defaultdict(list,
#                          {'middangeard': [2],
#                           'giellende': [5],
#                           'foddurwelan': [11]}),
#              'riddle33': defaultdict(list,
#                          {'beadoweorca': [7],
#                           'bordweall': [7],
#                           'heterune': [8]}),
#              'riddle35': defaultdict(list, {'heahcræft': [5], 'godweb': [11]}),
#              'riddle36': defaultdict(list, {'flodweg': [10]}),
#              'riddle39': defaultdict(list,
#                          {'sundorcræft': [4],
#                           'middangeard': [20],
#                           'wuldorcyning': [22],
#                           'ealdorgesceaft': [24]}),
#              'riddle40': defaultdict(list,
#                          {'anwald': [5],
#                           'middangeard': [13, 44],
#                           'bidsteal': [20],
#                           'segnberendra': [21],
#                           'heahcyning': [39],
#                           'beobread': [60],
#                           'regnwyrm': [71],
#                           'fenyce': [72],
#                           'wundorcræfte': [86],
#                           'garsecg': [94],
#                           'bellende': [107]}),
#              'riddle42': defaultdict(list, {'anfeng': [4], 'heanmod': [18]}),
#              'riddle43': defaultdict(list, {'cynewordum': [16]}),
#              'riddle46': defaultdict(list, {'frumbearn': [5]}),
#              'riddle47': defaultdict(list, {'stælgiest': [6]}),
#              'riddle48': defaultdict(list, {'galdorcwide': [8]}),
#              'riddle53': defaultdict(list, {'aglachade': [6], 'aglac': [6]}),
#              'riddle54': defaultdict(list, {'hægsteald': [4]}),
#              'riddle55': defaultdict(list, {'wudutreow': [4]}),
#              'riddle57': defaultdict(list,
#                          {'beorghleoþa': [3], 'bearonæssas': [6]}),
#              'riddle60': defaultdict(list,
#                          {'merefaroþe': [3], 'lagufæðme': [8]}),
#              'riddle63': defaultdict(list, {'seledream': [2]}),
#              'riddle66': defaultdict(list,
#                          {'middangeard': [2, 10], 'merestream': [10]}),
#              'riddle67': defaultdict(list, {'þeodcyning': [2]}),
#              'riddle72': defaultdict(list, {'dægtid': [9]}),
#              'riddle77': defaultdict(list, {'sundhelm': [2]}),
#              'riddle80': defaultdict(list,
#                          {'eaxlgestealla': [2],
#                           'fyrdrinc': [3],
#                           'wordleana': [10]}),
#              'riddle81': defaultdict(list, {'aglac': [7]}),
#              'riddle83': defaultdict(list,
#                          {'fromcyn': [2, 8], 'middangeard': [12]}),
#              'riddle84': defaultdict(list,
#                          {'wuldorgimm': [27],
#                           'grundbedd': [31],
#                           'werþeod': [42]}),
#              'riddle88': defaultdict(list,
#                          {'wudubeam': [14], 'gumcynn': [18]}),
#              'riddle91': defaultdict(list,
#                          {'middelnihtum': [8], 'wælcræfte': [12]}),
#              'riddle93': defaultdict(list, {'dægrim': [9]}),
#              'riddle95': defaultdict(list, {'midwist': [9]}),
#              'therimingpoem': defaultdict(list,
#                          {'lagustream': [15],
#                           'ealdorstol': [24],
#                           'galdorwordum': [25],
#                           'gellende': [26],
#                           'burgsele': [31],
#                           'brondhord': [47],
#                           'sinniþ': [53],
#                           'wælgar': [62],
#                           'foldwela': [69],
#                           'feondscipe': [69]}),
#              'theruin': defaultdict(list,
#                          {'werþeod': [10],
#                           'weallwalan': [21],
#                           'burgræced': [22],
#                           'burnsele': [22],
#                           'heresweg': [23],
#                           'burgsteall': [29],
#                           'stanhofu': [39],
#                           'hringmere': [46]}),
#              'therunepoem': defaultdict(list,
#                          {'morstapa': [7],
#                           'anfeng': [9],
#                           'ordfruma': [11],
#                           'ætwist': [22],
#                           'beorsele': [41],
#                           'brimhengest': [48, 67],
#                           'garsecg': [80],
#                           'geswic': [95]}),
#              'theseafarer': defaultdict(list,
#                          {'cearselda': [6],
#                           'hrimgicelum': [18],
#                           'huilpan': [22],
#                           'stanclif': [24],
#                           'bealosiþa': [29],
#                           'brimlade': [31],
#                           'nihtscua': [32],
#                           'sealtyþa': [36],
#                           'elþeod': [39],
#                           'flodweg': [53],
#                           'breosthord': [56],
#                           'wræclast': [58],
#                           'modsefa': [60],
#                           'mereflod': [60],
#                           'hwælweg': [64],
#                           'ecghete': [71],
#                           'lastworda': [74],
#                           'middangeard': [91],
#                           'iuwine': [93]}),
#              'theseasonsforfasting': defaultdict(list,
#                          {'heahcyning': [5, 11, 54],
#                           'leodscipe': [9, 12],
#                           'heahcyninges': [11, 54],
#                           'eastertid': [56],
#                           'emniht': [69],
#                           'andfeng': [92],
#                           'anfeng': [111],
#                           'orþancum': [116],
#                           'wangstede': [146],
#                           'æfest': [212]}),
#              'solomonandsaturn': defaultdict(list,
#                          {'igland': [3],
#                           'larcræftas': [5],
#                           'mægenþrymm': [12],
#                           'eorlscipe': [13],
#                           'domdæge': [29, 288],
#                           'feohgestreon': [35],
#                           'getælrime': [42],
#                           'middangeard': [82, 187, 463, 475],
#                           'eðelrice': [113],
#                           'foreweard': [120],
#                           'folctoga': [126],
#                           'gartorn': [152],
#                           'bancofa': [157],
#                           'dægred': [224],
#                           'modsefa': [252, 430],
#                           'feorbuend': [295],
#                           'wopdropan': [300],
#                           'lyftfleogendra': [306],
#                           'heahgestreon': [339],
#                           'wanhogan': [341],
#                           'anhoga': [341],
#                           'geswic': [346],
#                           'inwitgecyndo': [353],
#                           'geondscinan': [368],
#                           'orlegstunde': [412],
#                           'dryhtscipe': [426],
#                           'frumsceaft': [456],
#                           'wudutelga': [462],
#                           'wissefa': [481],
#                           'frumscylda': [489],
#                           'wyrmgeardas': [513],
#                           'misgemynda': [540]}),
#              'soulandbodyi': defaultdict(list,
#                          {'þeodcyning': [13],
#                           'mægenþrymm': [30],
#                           'hæftned': [33],
#                           'gehæftnedest': [33],
#                           'fyrenlust': [35, 45],
#                           'boldwela': [60],
#                           'hancred': [69],
#                           'lofsang': [70],
#                           'eardungstowe': [72],
#                           'moldwyrmas': [73],
#                           'feldgangende': [82],
#                           'domdæge': [97],
#                           'hellegrund': [105],
#                           'heofondream': [105],
#                           'lamfæt': [132],
#                           'gemotstede': [151]}),
#              'soulandbodyii': defaultdict(list,
#                          {'mægenþrymm': [27],
#                           'firenlusta': [32, 42],
#                           'eardungstowe': [67],
#                           'moldwyrmas': [68],
#                           'frumsceaft': [75],
#                           'wiþerlean': [89],
#                           'domdæge': [90],
#                           'heofondream': [99]}),
#              'asummonstoprayer': defaultdict(list, {'þrymcyning': [3]}),
#              'vainglory': defaultdict(list,
#                          {'wordhord': [4],
#                           'dægrim': [13],
#                           'æscstede': [18],
#                           'breostsefa': [20],
#                           'modsefa': [22],
#                           'dryhtguma': [23],
#                           'hinderhoca': [35],
#                           'hygegar': [35],
#                           'inwitflan': [38],
#                           'wuldorcyning': [51, 78],
#                           'neosiþum': [56],
#                           'heresiþ': [61],
#                           'þrymcyning': [63],
#                           'þeodenstol': [63],
#                           'frumsceaft': [67]}),
#              'walderea': defaultdict(list,
#                          {'geswic': [3],
#                           'dryhtscipe': [8],
#                           'edwitscype': [15],
#                           'byrnhomon': [18],
#                           'ætstealle': [22],
#                           'forbigan': [27],
#                           'bigan': [27]}),
#              'waldereb': defaultdict(list, {'iulean': [8], 'feorhhord': [23]}),
#              'thewanderer': defaultdict(list,
#                          {'anhaga': [2],
#                           'lagulade': [4],
#                           'wræclast': [6, 33],
#                           'eardstapa': [7],
#                           'modsefa': [11, 20, 60],
#                           'hordcofan': [15],
#                           'breostcofan': [19],
#                           'goldwine': [23, 36],
#                           'selesecgas': [35],
#                           'anhoga': [41],
#                           'giefstol': [45],
#                           'cwidegiedda': [56],
#                           'maguþegn': [63],
#                           'middangeard': [63, 76],
#                           'hatheort': [67],
#                           'eardgeard': [86],
#                           'seledream': [94],
#                           'nihthelm': [97],
#                           'wyrmlicum': [99],
#                           'nihtscua': [105]}),
#              'thewhale': defaultdict(list,
#                          {'modgemynd': [4],
#                           'frecnes': [21],
#                           'heahfyr': [23],
#                           'garsecg': [30],
#                           'cwicsusle': [39],
#                           'feorgbona': [42],
#                           'heoloþhelme': [46],
#                           'mereweard': [54],
#                           'wuldorcyning': [68, 86],
#                           'edwylme': [74],
#                           'hlinduru': [79],
#                           'utsiþ': [80]}),
#              'widsith': defaultdict(list,
#                          {'wordhord': [2],
#                           'þeodenstol': [14],
#                           'eorlscipe': [41, 142],
#                           'fifeldore': [44],
#                           'scillingrime': [93],
#                           'bicwom': [95],
#                           'dryhtcwen': [99],
#                           'giellende': [129]}),
#              "thewife'slament": defaultdict(list,
#                          {'wræcsiþa': [6, 39],
#                           'leodfruma': [9],
#                           'weaþearfe': [11],
#                           'freondscipe': [26],
#                           'actreo': [29, 37],
#                           'burgtunas': [32],
#                           'fromsiþ': [34],
#                           'stanhliþe': [49],
#                           'dreorsele': [51]}),
#              'wulfandeadwacer': defaultdict(list,
#                          {'eadwacer': [1, 17], 'widlast': [10]})})
